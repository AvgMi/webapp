# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("parkinsons.csv")

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df.shape
# Out:
# (195, 24)

# %%
df.drop("name",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MDVP:Fo(Hz)       195 non-null    float64
#  1   MDVP:Fhi(Hz)      195 non-null    float64
#  2   MDVP:Flo(Hz)      195 non-null    float64
#  3   MDVP:Jitter(%)    195 non-null    float64
#  4   MDVP:Jitter(Abs)  195 non-null    float64
#  5   MDVP:RAP          195 non-null    float64
#  6   MDVP:PPQ          195 non-null    float64
#  7   Jitter:DDP        195 non-null    float64
#  8   MDVP:Shimmer      195 non-null    float64
#  9   MDVP:Shimmer(dB)  195 non-null    float64
#  10  Shimmer:APQ3      195 non-null    float64
#  11  Shimmer:APQ5      195 non-null    float64
#  12  MDVP:APQ          195 non-null    float64
#  13  Shimmer:DDA       195 non-null    float64
#  14  NHR               195 non-null    float64
#  15  HNR               195 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap='viridis')
plt.show()

# %%
sns.scatterplot(x = df['Shimmer:DDA'], y = df['MDVP:Shimmer'], hue = df['status'])
# Out:
# <AxesSubplot:xlabel='Shimmer:DDA', ylabel='MDVP:Shimmer'>

# %%
df["status"].value_counts()             #number of people with diabetes and without diabetes
a=sns.countplot(x="status" , data=df, palette=['#432371',"#FAAE7B"])      # countplot
a.set_xlabel("Outcome [0:negative for parkinsons 1:positive for parkinsons]")
plt.show()

# %%
print(" negative for parkinsons :- ", df["status"].value_counts()[0])
print(" positive for parkinsons:- ", df["status"].value_counts()[1])
# Out:
#  negative for parkinsons :-  48
#  positive for parkinsons:-  147

# %%
NP=df["status"].value_counts()[0]
PP=df["status"].value_counts()[1]
c=len(df)

# %%
P=(NP/c)*100
Q=(PP/c)*100
print("Total non positive for parkinsons patients= ",P)
print("Total positive for parkinsons patients=",Q)
# Out:
# Total non positive for parkinsons patients=  24.615384615384617
# Total positive for parkinsons patients= 75.38461538461539

# %%
X = df.drop("status",axis=1)
y = df["status"]

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix , classification_report

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=0)

# %%
model = SVC(kernel="linear")

# %%
model.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(X_test)

# %%
print(accuracy_score(y_pred,y_test))
# Out:
# 0.8205128205128205

# %%
acc_score1 = accuracy_score(y_test, y_pred)

# %%
print(acc_score1*100,"%")
# Out:
# 82.05128205128204 %

# %%
confusion_matrix = confusion_matrix(y_test,y_pred)

# %%
print(confusion_matrix)
# Out:
# [[ 7  3]
#  [ 4 25]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.70      0.67        10
#            1       0.89      0.86      0.88        29
#
#     accuracy                           0.82        39
#    macro avg       0.76      0.78      0.77        39
# weighted avg       0.83      0.82      0.82        39

# %%
import seaborn as sns

ax = sns.heatmap(confusion_matrix, annot=True, cmap='Blues')

ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
# model deployment
import pickle

# %%
fname = "Parkinsons_pred.sav"

pickle.dump(model, open(fname,"wb"))

# %%
loading = pickle.load(open("Parkinsons_pred.sav","rb"))

# %%
ip = np.array([197.07600,206.89600,192.05500,0.00289,0.00001,0.00166,0.00168,0.00498,0.01098,0.09700,0.00563,0.00680,0.00802,0.01689,0.00339,26.77500,0.422229,0.741367,-7.348300,0.177551,1.743867,0.085569]
)

prediction = loading.predict(ip.reshape(1,-1))
print(prediction)

if (prediction[0] == 0):
  print("The Person does not have Parkinsons Disease")

else:
  print("The Person has Parkinsons")
# Out:
# [0]
# The Person does not have Parkinsons Disease
